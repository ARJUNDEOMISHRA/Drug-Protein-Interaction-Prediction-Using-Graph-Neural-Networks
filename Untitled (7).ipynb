# %% [markdown]
# ## INTRODUCTION TO  convolutional Neural Networks and Computer Vision with TensorFlow

# %% [markdown]
# computer vision is the practice of writing algorithm which can discover patterns in visual data. Sich as the camera of a self-driving car **recognizing the car in front**

# %% [markdown]
# ## get the data

# %%
import requests
import zipfile
import os

# Download dataset
url = "https://storage.googleapis.com/ztm_tf_course/food_vision/pizza_steak.zip"
zip_path = "pizza_steak.zip"

r = requests.get(url, stream=True)
with open(zip_path, "wb") as f:
    for chunk in r.iter_content(chunk_size=1024*1024):
        if chunk:
            f.write(chunk)

# Extract dataset
extract_dir = "pizza_steak_data"
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_dir)

# List contents to verify
print(os.listdir(extract_dir))
# Out:
# ['pizza_steak']

# %% [markdown]
# ## inspect the data (become one with it)

# %% [raw]
# A very crucial ytep at eh beginning of any machine laratning project is becoming one wtih the data.
#
# And for a compute vision project... this usually means visualizing many smaples of your data.

# %%
import os
folder = "pizza_steak_data"

# %%
print(os.listdir(folder))
# Out:
# ['pizza_steak']

# %%
import os

folder = "pizza_steak_data"  # replace with your extracted folder path
print(os.listdir(folder))
# Out:
# ['pizza_steak']

# %%
import os
print(os.listdir("pizza_steak_data"))
# Out:
# ['pizza_steak']

# %%
# !dir pizza_steak/train/
# Out:
# Parameter format not correct - "rain".

# %%
# !dir pizza_steak_data
# Out:
#  Volume in drive C is Acer
#  Volume Serial Number is D4CA-BA5B
#
#  Directory of C:\Users\arjun\COMPUTERVISSION WITH TENSORFLOW\pizza_steak_data
#
# 07-10-2025  16:44    <DIR>          .
# 07-10-2025  16:59    <DIR>          ..
# 07-10-2025  16:44    <DIR>          pizza_steak
#                0 File(s)              0 bytes
#                3 Dir(s)  257,407,074,304 bytes free

# %%
# !ls pizza_steak/train/
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !dir pizza_steak\train
# Out:
# The system cannot find the file specified.

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\arjun\COMPUTERVISSION WITH TENSORFLOW

# %%
import os

for dirpath, dirnames, filenames in os.walk("pizza_steak"):
    print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")

# %%
print(os.path.exists("pizza_steak"))
# Out:
# False

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\arjun\COMPUTERVISSION WITH TENSORFLOW

# %%
for dirpath, dirnames, filenames in os.walk(r"C:\Users\arjun\COMPUTERVISSION WITH TENSORFLOW\data\pizza_steak"):
    print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")

# %%
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'pizza_steak.zip', 'pizza_steak_data', 'Untitled.ipynb']

# %%
import os

for dirpath, dirnames, filenames in os.walk("pizza_steak_data"):
    print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")
# Out:
# There are 1 directories and 0 images in 'pizza_steak_data'.
# There are 2 directories and 0 images in 'pizza_steak_data\pizza_steak'.
# There are 2 directories and 0 images in 'pizza_steak_data\pizza_steak\test'.
# There are 0 directories and 250 images in 'pizza_steak_data\pizza_steak\test\pizza'.
# There are 0 directories and 250 images in 'pizza_steak_data\pizza_steak\test\steak'.
# There are 2 directories and 0 images in 'pizza_steak_data\pizza_steak\train'.
# There are 0 directories and 750 images in 'pizza_steak_data\pizza_steak\train\pizza'.
# There are 0 directories and 750 images in 'pizza_steak_data\pizza_steak\train\steak'.

# %%
# !dir -la pizza_Steak_data
# Out:
#  Volume in drive C is Acer
#  Volume Serial Number is D4CA-BA5B
#
#  Directory of C:\Users\arjun\COMPUTERVISSION WITH TENSORFLOW
#
#
#  Directory of C:\Users\arjun\COMPUTERVISSION WITH TENSORFLOW\pizza_Steak_data
#
# 07-10-2025  16:44    <DIR>          .
# 08-10-2025  11:09    <DIR>          ..
# 07-10-2025  16:44    <DIR>          pizza_steak
#                0 File(s)              0 bytes
#                3 Dir(s)  257,884,631,040 bytes free
# File Not Found

# %%
ls -la pizza_steak_data
# Out:
#  Volume in drive C is Acer
#  Volume Serial Number is D4CA-BA5B
#
#  Directory of C:\Users\arjun\COMPUTERVISSION WITH TENSORFLOW
#
#
#  Directory of C:\Users\arjun\COMPUTERVISSION WITH TENSORFLOW\pizza_steak_data
#
# 07-10-2025  16:44    <DIR>          .
# 08-10-2025  11:11    <DIR>          ..
# 07-10-2025  16:44    <DIR>          pizza_steak
#                0 File(s)              0 bytes
#                3 Dir(s)  257,875,857,408 bytes free
# File Not Found

# %%
# !dir /s pizza_steak_data
# Out:
#  Volume in drive C is Acer
#  Volume Serial Number is D4CA-BA5B
#
#  Directory of C:\Users\arjun\COMPUTERVISSION WITH TENSORFLOW\pizza_steak_data
#
# 07-10-2025  16:44    <DIR>          .
# 08-10-2025  11:11    <DIR>          ..
# 07-10-2025  16:44    <DIR>          pizza_steak
#                0 File(s)              0 bytes
#
#  Directory of C:\Users\arjun\COMPUTERVISSION WITH TENSORFLOW\pizza_steak_data\pizza_steak
#
# 07-10-2025  16:44    <DIR>          .
# 07-10-2025  16:44    <DIR>          ..
# 07-10-2025  16:44    <DIR>          test
# 07-10-2025  16:44    <DIR>          train
#                0 File(s)              0 bytes
#
#  Directory of C:\Users\arjun\COMPUTERVISSION WITH TENSORFLOW\pizza_steak_data\pizza_steak\test
#
# 07-10-2025  16:44    <DIR>          .
# 07-10-2025  16:44    <DIR>          ..
# 07-10-2025  16:44    <DIR>          pizza
# 07-10-2025  16:44    <DIR>          steak
#                0 File(s)              0 bytes
#
# ...

# %%
num_steak_images_train = len(os.listdir("pizza_steak_data/train/steak"))
num_steak_images_train
# Out:
#   Cell In[53], line 1
#     num_steak_images_train = len(os.listdir("C:\Users\arjun\COMPUTERVISSION WITH TENSORFLOW/train/steak"))
#                                             ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import os
print(os.listdir("pizza_steak_data/train"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[54], line 2
#       1 import os
# ----> 2 print(os.listdir("pizza_steak_data/train"))
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'pizza_steak_data/train'

# %%
import os
print(os.listdir("pizza_steak_data"))
# Out:
# ['pizza_steak']

# %%
import os
print(os.listdir("pizza_steak_data/pizza_steak"))
# Out:
# ['test', 'train']

# %%
num_steak_images_train = len(os.listdir("pizza_steak_data/pizza_steak/train/steak"))
print(num_steak_images_train)
# Out:
# 750

# %% [markdown]
# To visulaize our images, fist let's get the class names programmatically.

# %%
import pathlib
import numpy as np

# Correct Path with capital P
data_dir = pathlib.Path("pizza_steak_data/pizza_steak/steak")

# List all files (image names) inside the folder
class_names = np.array(sorted([item.name for item in data_dir.glob("*")]))
print(class_names)
# Out:
# []

# %%
import pathlib
import numpy as np 
data_dir = pathlib.Path("pizza_steak_data")
class_names = np.array(sorted([item.name for item in data_dir.glob("*")]))

print(class_names)
# Out:
# ['pizza_steak']

# %%
import pathlib
import numpy as np 
data_dir = pathlib.Path("pizza_steak_data")
class_names = np.array(sorted([item.name for item in data_dir.glob("*")]))
class_names = class_names[:1]
print(class_names)
# Out:
# ['pizza_steak']

# %%
#let's visulaize our images

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg  # fixed import
import os
import random

def view_random_image(target_dir, target_class):
    # Create full path to the class folder
    target_folder = os.path.join(target_dir, target_class)
    
    # Get a random image from the folder
    random_image = random.choice(os.listdir(target_folder))
    print(f"Random image file: {random_image}")
    
    # Read and display the image
    img = mpimg.imread(os.path.join(target_folder, random_image))
    plt.imshow(img)
    plt.title(target_class)
    plt.axis("off")
    plt.show()
    
    print(f"Image shape: {img.shape}")
    return img

# %%
img = view_random_image(
    target_dir="pizza_steak_data/pizza_steak/train",
    target_class="steak"
)
# Out:
# Random image file: 2535431.jpg
# Image shape: (512, 512, 3)

# %%
import os
print(os.listdir("pizza_steak_data/pizza_steak"))
# Out:
# ['test', 'train']

# %%
import tensorflow as tf
tf.constant(img)
# Out:
# <tf.Tensor: shape=(512, 512, 3), dtype=uint8, numpy=
# array([[[ 65,  27,  16],
#         [ 67,  29,  18],
#         [ 64,  26,  15],
#         ...,
#         [181, 110,  68],
#         [181, 109,  69],
#         [182, 110,  70]],
#
#        [[ 66,  28,  17],
#         [ 66,  28,  17],
#         [ 63,  25,  14],
#         ...,
#         [181, 110,  68],
#         [180, 108,  68],
#         [180, 108,  68]],
#
#        [[ 68,  30,  19],
#         [ 67,  29,  18],
#         [ 63,  25,  14],
#         ...,
#         [182, 111,  69],
#         [180, 109,  67],
#         [180, 108,  68]],
#
#        ...,
#
#        [[ 46,  39,  46],
#         [ 46,  39,  46],
#         [ 48,  42,  46],
#         ...,
#         [ 77,  90, 106],
#         [ 75,  88, 104],
#         [ 73,  86, 102]],
#
#        [[ 48,  41,  48],
#         [ 47,  40,  47],
#         [ 48,  42,  46],
#         ...,
#         [ 76,  89, 105],
#         [ 76,  89, 105],
#         [ 74,  90, 105]],
#
#        [[ 51,  44,  51],
# ...
